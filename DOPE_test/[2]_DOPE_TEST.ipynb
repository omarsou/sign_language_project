# %%
# !nvidia-smi -L
# Out:
# GPU 0: Tesla P100-PCIE-16GB (UUID: GPU-38f4a6dd-dd38-5224-e20c-919194a99f0d)

# %%
# %cd /content/drive/MyDrive/sign_language
# !python dope.py --model DOPE_v1_0_0 --image test.jpg
# Out:
# /content/drive/MyDrive/sign_language
# Loading model DOPE_v1_0_0
# Loading image test.jpg
# Running DOPE
# Postprocessing
# Displaying results
# 	 test.jpg_DOPE_v1_0_0.jpg

# %%
# %cd /content/drive/MyDrive/sign_language
# !python dope.py --model DOPE_v1_0_0 --image test1.jpg
# Out:
# /content/drive/MyDrive/sign_language
# Loading model DOPE_v1_0_0
# Loading image test1.jpg
# Running DOPE
# Postprocessing
# Displaying results
# 	 test1.jpg_DOPE_v1_0_0.jpg

# %%
# %cd /content/drive/MyDrive/sign_language
# !python dope.py --model DOPE_v1_0_0 --image test2.jpg
# Out:
# /content/drive/MyDrive/sign_language
# Loading model DOPE_v1_0_0
# Loading image test2.jpg
# Running DOPE
# Postprocessing
# Displaying results
# 	 test2.jpg_DOPE_v1_0_0.jpg
