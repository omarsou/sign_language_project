# %%
# !nvidia-smi -L
# %tensorflow_version 2.x
# Out:
# GPU 0: Tesla V100-SXM2-16GB (UUID: GPU-72ef3f96-af3a-36b7-4455-fa7276c8a1e8)

# %%
#!chmod 755 -R /content/drive/MyDrive/sign_language/data/
#!/content/drive/MyDrive/sign_language/data/download.sh
"""Requirements removed"""
#conda==4.8.0
#conda-package-handling==1.6.0
#tensorboard==2.1.2
#tensorflow-estimator==2.1.2 to tensorflow-estimator==2.1.0
#warmup-scheduler==0.1.1
# Out:
# 'Requirements removed'

# %%
# !pip3 install --upgrade tensorflow-gpu==2.1.0

# %%
# !pip3 install -r /content/drive/MyDrive/sign_language/requirements.txt

# %%
# %cd /content/drive/MyDrive/sign_language
# !python -m signjoey train configs/sign_features_avg.yaml
# Out:
# Streaming output truncated to the last 5000 lines.
# 	WER 75.02	(DEL: 72.24,	INS: 0.29,	SUB: 2.48)
# 	BLEU-4 16.02	(BLEU-1: 40.78,	BLEU-2: 27.53,	BLEU-3: 20.36,	BLEU-4: 16.02)
# 	CHRF 39.54	ROUGE 42.56
# 2021-01-01 21:33:37,333 Logging Recognition and Translation Outputs
# 2021-01-01 21:33:37,333 ========================================================================================================================
# 2021-01-01 21:33:37,333 Logging Sequence: dev/06January_2010_Wednesday_heute-3530
# 2021-01-01 21:33:37,333 	Gloss Reference :	WIND KOMMEN DANN SCHNEE WITTERUNG
# 2021-01-01 21:33:37,333 	Gloss Hypothesis:	**** ****** **** ****** *********
# 2021-01-01 21:33:37,333 	Gloss Alignment :	D    D      D    D      D
# 2021-01-01 21:33:37,334 	--------------------------------------------------------------------------------------------------------------------
# ...
