# %%
import yaml

# %%
with open("/content/drive/MyDrive/sign_language/configs/sign.yaml") as f:
     list_doc = yaml.load(f)

# %%
list_doc['data']['feature_size_cnn'] = 1024

# %%
list_doc['model']['encoder']['hidden_size'] = 512 + 512

# %%
list_doc['model']['decoder']['hidden_size'] = 512 + 512
list_doc['model']['decoder']['embeddings']['embedding_dim'] = 512 + 512

# %%
list_doc['data']['train'] = ['phoenix14t.pami0.traincnn0', 'phoenix14t.pami0.traincnn1', 'phoenix14t.pami0.traincnn2',
                             'phoenix14t.pami0.traincnn3', 'phoenix14t.pami0.traincnn4', 'phoenix14t.pami0.traincnn5']

# %%
list_doc
# Out:
# {'data': {'data_path': './data/',
#   'dev': 'phoenix14t.pami0.dev',
#   'feature_size': 1024,
#   'feature_size_cnn': 1024,
#   'gls': 'gloss',
#   'level': 'word',
#   'max_sent_length': 400,
#   'random_dev_subset': -1,
#   'random_train_subset': -1,
#   'sgn': 'sign',
#   'test': 'phoenix14t.pami0.test',
#   'train': ['phoenix14t.pami0.traincnn0',
#    'phoenix14t.pami0.traincnn1',
#    'phoenix14t.pami0.traincnn2',
#    'phoenix14t.pami0.traincnn3',
#    'phoenix14t.pami0.traincnn4',
#    'phoenix14t.pami0.traincnn5'],
#   'txt': 'text',
#   'txt_lowercase': True,
#   'version': 'phoenix_2014_trans'},
#  'model': {'bias_initializer': 'zeros',
#   'decoder': {'dropout': 0.1,
#    'embeddings': {'activation_type': 'softsign',
#     'dropout': 0.1,
#     'embedding_dim': 512,
#     'norm_type': 'batch',
#     'scale': False},
#    'ff_size': 2048,
#    'hidden_size': 512,
#    'num_heads': 8,
#    'num_layers': 3,
#    'type': 'transformer'},
#   'embed_init_gain': 1.0,
# ...

# %%
with open("/content/drive/MyDrive/sign_language/configs/sign_cnn_avg.yaml", "w") as f:
     yaml.dump(list_doc, f)
